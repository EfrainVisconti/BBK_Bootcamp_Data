# %% [markdown]
# # Ejercicios de Seaborn

# %% [markdown]
# ### 1. Importa pandas, pyplot y seaborn.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Activa matplotlib de forma estática.

# %%
# %matplotlib inline

# %% [markdown]
# ### 3. Lee 'Pokemon.csv', lee la primera columna del csv como índice del DataFrame.

# %%
df = pd.read_csv('data/Pokemon.csv', encoding="latin-1", index_col=0)
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %% [markdown]
# ### 4. Mira las primeras filas del dataset para hacerte una idea de los datos cargados.

# %%
df.head(10)
# Out:
#           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1    Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2      Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3     Venusaur  Grass  Poison    525  80      82       83      100      100
# 4   Charmander   Fire     NaN    309  39      52       43       60       50
# 5   Charmeleon   Fire     NaN    405  58      64       58       80       65
# 6    Charizard   Fire  Flying    534  78      84       78      109       85
# 7     Squirtle  Water     NaN    314  44      48       65       50       64
# 8    Wartortle  Water     NaN    405  59      63       80       65       80
# 9    Blastoise  Water     NaN    530  79      83      100       85      105
# 10    Caterpie    Bug     NaN    195  45      30       35       20       20
#
#     Speed  Stage  Legendary
# #
# 1      45      1      False
# 2      60      2      False
# 3      80      3      False
# 4      65      1      False
# 5      80      2      False
# 6     100      3      False
# 7      43      1      False
# 8      58      2      False
# 9      78      3      False
# 10     45      1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 1 to 151
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       151 non-null    object
#  1   Type 1     151 non-null    object
#  2   Type 2     67 non-null     object
#  3   Total      151 non-null    int64
#  4   HP         151 non-null    int64
#  5   Attack     151 non-null    int64
#  6   Defense    151 non-null    int64
#  7   Sp. Atk    151 non-null    int64
#  8   Sp. Def    151 non-null    int64
#  9   Speed      151 non-null    int64
#  10  Stage      151 non-null    int64
#  11  Legendary  151 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 14.3+ KB

# %%
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  151.00000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean   407.07947   64.211921   72.549669   68.225166   67.139073   66.019868
# std     99.74384   28.590117   26.596162   26.916704   28.534199   24.197926
# min    195.00000   10.000000    5.000000    5.000000   15.000000   20.000000
# 25%    320.00000   45.000000   51.000000   50.000000   45.000000   49.000000
# 50%    405.00000   60.000000   70.000000   65.000000   65.000000   65.000000
# 75%    490.00000   80.000000   90.000000   84.000000   87.500000   80.000000
# max    680.00000  250.000000  134.000000  180.000000  154.000000  125.000000
#
#             Speed       Stage
# count  151.000000  151.000000
# mean    68.933775    1.582781
# std     26.746880    0.676832
# min     15.000000    1.000000
# 25%     46.500000    1.000000
# 50%     70.000000    1.000000
# 75%     90.000000    2.000000
# max    140.000000    3.000000

# %% [markdown]
# ### 5. Haz un scatter plot con lmplot(), que es el método que pinta una regresión lineal. Pasa el DataFrame como argumento del método en el parámetro llamado data.

# %%
sns.lmplot(data=df, x='Attack', y='Defense')

# %% [markdown]
# ### 6. No queremos ver la línea recta de la regresión lineal. Prueba a añadir fit_reg a falso.

# %%
sns.lmplot(data=df, x='Attack', y='Defense', fit_reg=False)

# %%
sns.scatterplot(data=df, x='Attack', y='Defense')
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# ### 7. Vamos a decir qué variable (columna del DataFrame) codifica los colores (hue), que el hue sea el Stage.

# %%
sns.scatterplot(data=df, x='Attack', y='Defense', hue='Stage')
# Out:
# <Axes: xlabel='Attack', ylabel='Defense'>

# %% [markdown]
# ### 8. Limita el eje x entre 20 y 100.

# %%
sns.scatterplot(data=df, x='Attack', y='Defense', hue='Stage')
plt.xlim(20,100);

# %% [markdown]
# ### 9. Dibuja un diagrama de cajas con el dataframe.

# %%
sns.boxplot(x=df['Attack']); # Como no especifica, puedo hacerlo de una variable, varias o todas

# %%
sns.boxplot(data=df[['Attack','Defense','HP']]);

# %% [markdown]
# ### 10. No nos interesan las columnas Total, Stage ni Legendary. Bórralos del DataFrame y vuelve a dibujar el diagrama de cajas

# %%
df.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
df_10 = df.drop(columns=['Total','Stage','Legendary'])

# %%
plt.figure(figsize=(20,15))
sns.boxplot(data=df[["HP",'Attack','Defense',"Sp. Atk","Sp. Def","Speed"]])
# Out:
# <Axes: >

# %% [markdown]
# ### 11. Mira cuántos 'Type 1' diferentes hay en el DataFrame.

# %%
len(df['Type 1'].unique())
# Out:
# 15

# %%
df['Type 1'].nunique()
# Out:
# 15

# %% [markdown]
# ### 12. Quédate del Dataframe solo con los 'Type 1' iguales a 'Grass', 'Fire' o 'Water' y llamalo df_gfw.

# %%
df_gfw = df[df['Type 1'].isin(['Grass','Fire','Water'])]
df_gfw.head(15)
# Out:
#           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1    Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2      Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3     Venusaur  Grass  Poison    525  80      82       83      100      100
# 4   Charmander   Fire     NaN    309  39      52       43       60       50
# 5   Charmeleon   Fire     NaN    405  58      64       58       80       65
# 6    Charizard   Fire  Flying    534  78      84       78      109       85
# 7     Squirtle  Water     NaN    314  44      48       65       50       64
# 8    Wartortle  Water     NaN    405  59      63       80       65       80
# 9    Blastoise  Water     NaN    530  79      83      100       85      105
# 37      Vulpix   Fire     NaN    299  38      41       40       50       65
# 38   Ninetales   Fire     NaN    505  73      76       75       81      100
# 43      Oddish  Grass  Poison    320  45      50       55       75       65
# 44       Gloom  Grass  Poison    395  60      65       70       85       75
# 45   Vileplume  Grass  Poison    490  75      80       85      110       90
# 54     Psyduck  Water     NaN    320  50      52       48       65       50
#
#     Speed  Stage  Legendary
# #
# 1      45      1      False
# 2      60      2      False
# 3      80      3      False
# 4      65      1      False
# 5      80      2      False
# 6     100      3      False
# 7      43      1      False
# 8      58      2      False
# 9      78      3      False
# 37     65      1      False
# 38    100      2      False
# 43     30      1      False
# 44     40      2      False
# 45     50      3      False
# 54     55      1      False

# %% [markdown]
# ### 13. Usa un estilo 'whitegrid'.

# %%
sns.set_style('whitegrid')

# %% [markdown]
# ### 14. Pinta diagramas de violín con el df_gfw.

# %%
sns.violinplot(data=df_gfw, x='Type 1', y='Attack');

# %% [markdown]
# ### 15. Escribe una lista de colores con valores '#78C850', '#F08030',  '#6890F0'.

# %%
p_colores = ['#78C850', '#F08030', '#6890F0']

# %% [markdown]
# ### 16. Pinta de nuevo los diagramas de violín añadiendo esos colores en la paleta (palette).

# %%
sns.violinplot(data=df_gfw, x='Type 1', y='Attack', palette=p_colores);
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_4364\3196817270.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_gfw, x='Type 1', y='Attack', palette=p_colores);

# %% [markdown]
# ### 17. Con el diagrama de violín vemos la forma de la distribución, pero no sabemos si Grass tiene muchos puntos y Fire tiene muy pocos. Para ver esto, usamos el swarmplot. Pinta el último diagrama de violines pero con un swarmplot en lugar de un violin.

# %%
sns.swarmplot(data=df_gfw, x='Type 1', y='Attack', palette=p_colores);
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_4364\2392267381.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=df_gfw, x='Type 1', y='Attack', palette=p_colores);

# %% [markdown]
# ### 18. Queremos ver los violines a la vez que los swarm, los podemos pintar juntos. Elimina los diagramas de caja dentro de los violines con el parámetro inner = None y pon una saturación de 0.9. Pon un título con pyplot (como siempre).

# %%
sns.violinplot(data=df_gfw, x='Type 1', y='Attack', palette=p_colores, inner=None, saturation=0.9)
sns.swarmplot(data=df_gfw, x='Type 1', y='Attack', color='black')
plt.title("Ataques de pokemones");
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_4364\3885757221.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df_gfw, x='Type 1', y='Attack', palette=p_colores, inner=None, saturation=0.9)

# %% [markdown]
# ### 19. Veamos la función melt() de pandas. Melt toma los valores de varias columnas y los junta todos en una misma columna nueva.
#
# Dado un DataFrame, melt recibe varios parámetros:
# * qué columnas del DataFrame se quedan igual.
# * qué nombres de columnas del dataframe pasan a ser una columna nueva.
# * cómo queremos llamar esas nuevas columnas.
#
# Primero recuerda el Dataframe df_gfw con las primeras 5 filas.

# %%
df_gfw.head(5)
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %% [markdown]
# ### 20. Queremos dejar igual las variables 'Name' y 'Type 1'. Queremos añadir una columa nueva cuyos valores sean las columnas que queremos apilar y que se llame 'New Column'. Escribimos df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=[...], var_name='New Column').

# %%
df_melt = df_gfw.melt(id_vars=['Name', 'Type 1'], value_vars=['Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed','Stage'], var_name='New Column')

# %%
df_melt.tail(10)
# Out:
#          Name Type 1 New Column  value
# 406   Seaking  Water      Stage      2
# 407    Staryu  Water      Stage      1
# 408   Starmie  Water      Stage      2
# 409    Magmar   Fire      Stage      1
# 410  Magikarp  Water      Stage      1
# 411  Gyarados  Water      Stage      2
# 412    Lapras  Water      Stage      1
# 413  Vaporeon  Water      Stage      2
# 414   Flareon   Fire      Stage      2
# 415   Moltres   Fire      Stage      1

# %%
df_melt[df_melt['Name']=='Charmander']
# Out:
#            Name Type 1 New Column  value
# 3    Charmander   Fire      Total    309
# 55   Charmander   Fire         HP     39
# 107  Charmander   Fire     Attack     52
# 159  Charmander   Fire    Defense     43
# 211  Charmander   Fire    Sp. Atk     60
# 263  Charmander   Fire    Sp. Def     50
# 315  Charmander   Fire      Speed     65
# 367  Charmander   Fire      Stage      1

# %% [markdown]
# ### 21. Pintamos el swarmplot con el melted y entendemos la información.

# %%
sns.swarmplot(data=df_melt, x='New Column', y='value');
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 26.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 28.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 30.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 86.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
df_melt['New Column'].unique()
# Out:
# array(['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed',
#        'Stage'], dtype=object)

# %%
sns.stripplot(data=df_melt, x='New Column', y='value')
plt.ylim(20,200);

# %% [markdown]
# ### 22. Basándote en el gráfico anterior, define el tamaño de la figura en (10,6) (usa plt). En el swarmplot añade el argumento dodge a True y usa la anterior paleta de colores Pokemon.
#
# Dodge en inglés es "esquivar", ¿qué diferencia ves?
#
# Usando plt:
# * fija el límite del eje Y entre 0 y 200.
# * fija la leyenda con bbox_to_anchor arriba a la izquierda. Pista: (x, y, width, height).

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(data=df_melt, x='New Column', y='value', hue='Type 1', palette=p_colores, dodge=True)
plt.ylim(0,200)
plt.legend(bbox_to_anchor=(0.15,1));
# Out:
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 8.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# c:\Users\Usuario\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3370: UserWarning: 60.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Observa que incluso usando Seaborn, usamos Pyplot para trabajar con los ejes, la leyenda y el tamaño. Lo importante es que Seaborn y Pyplot conviven bien juntos

# %% [markdown]
# ### 23. Mapas de calor.
# * Calcula las correlaciones del primer DataFrame original df. Pista: las correlaciones se calculan con el método corr().
#
# Recuerda: las correlaciones miden entre dos variables, si varío una, cuánto me varía la otra (cómo están de relacionadas)

# %%
df.head()
# Out:
#          Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 1   Bulbasaur  Grass  Poison    318  45      49       49       65       65
# 2     Ivysaur  Grass  Poison    405  60      62       63       80       80
# 3    Venusaur  Grass  Poison    525  80      82       83      100      100
# 4  Charmander   Fire     NaN    309  39      52       43       60       50
# 5  Charmeleon   Fire     NaN    405  58      64       58       80       65
#
#    Speed  Stage  Legendary
# #
# 1     45      1      False
# 2     60      2      False
# 3     80      3      False
# 4     65      1      False
# 5     80      2      False

# %%
df.corr(numeric_only=True)
# Out:
#               Total        HP    Attack   Defense   Sp. Atk   Sp. Def  \
# Total      1.000000  0.576591  0.670939  0.508694  0.680745  0.774383
# HP         0.576591  1.000000  0.306768  0.119782  0.236649  0.490978
# Attack     0.670939  0.306768  1.000000  0.491965  0.146312  0.369069
# Defense    0.508694  0.119782  0.491965  1.000000  0.187569  0.139912
# Sp. Atk    0.680745  0.236649  0.146312  0.187569  1.000000  0.522907
# Sp. Def    0.774383  0.490978  0.369069  0.139912  0.522907  1.000000
# Speed      0.506950 -0.040939  0.194701 -0.053252  0.411516  0.392656
# Stage      0.504224  0.249207  0.361321  0.270861  0.391712  0.358308
# Legendary  0.328412  0.172441  0.147486  0.141576  0.334159  0.215314
#
#               Speed     Stage  Legendary
# Total      0.506950  0.504224   0.328412
# HP        -0.040939  0.249207   0.172441
# Attack     0.194701  0.361321   0.147486
# Defense   -0.053252  0.270861   0.141576
# Sp. Atk    0.411516  0.391712   0.334159
# Sp. Def    0.392656  0.358308   0.215314
# Speed      1.000000  0.240042   0.199969
# Stage      0.240042  1.000000  -0.142508
# Legendary  0.199969 -0.142508   1.000000

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only=True), annot=True, square=True);

# %% [markdown]
# * ¿La correlación entre qué valores se encuentra?
# * La autocorrelación es la correlación de una variable consigo misma, ¿qué aprecias?
# * Encuentra dos variables que veas que están fuertemente relacionadas según la correlación.
# * Si tuvieras una matriz de correlación muy grande y te cobrasen por cada dato que lees, ¿qué harías?

# %% [markdown]
# ### 24. Pinta el histograma y la densidad de probabilidad del nivel de defensa usando el DataFrame original.

# %%
sns.displot(df['Defense'], kde=True);

# %% [markdown]
# ### 25. Pinta un diagrama de barras de la columna 'Type 1' usando el DataFrame original. Usa un sns.countplot, plt.xticks y gira las etiquetas.

# %%
sns.countplot(x='Type 1', data=df)
plt.xticks(rotation=-45, fontsize=10);

# %% [markdown]
# ### 26. Usa catplot con el DataFrame original. Muestra el valor de Defense según el 'Type 1', muestra un subplot para legendarios y otro para no legendarios y divide los colores según el Type 2.

# %%
chart = sns.catplot(data=df, x='Type 1', y='Defense', hue='Type 2', col='Legendary') #Cuidado, hay Nan en Type 2 por lo que no apareceran coloreados
chart.set_xticklabels(rotation=45);

# %% [markdown]
# ### 27. Muestra una función distribución de probabilidad con kdeplot (curvas de nivel) de la defensa respecto al ataque. Di un bin 2D donde caigan muchos puntos (ataque, defensa).

# %%
sns.kdeplot(x=df['Attack'], y=df['Defense']);

# %% [markdown]
# ### 28. Pinta una distribución de probabilidad conjunta, pintando la defensa respecto al ataque del DataFrame original. Pista: jointplot()

# %%
sns.jointplot(x='Attack', y='Defense', data=df, kind='kde'); #funciones de densidad es lo que vemos a los lados
